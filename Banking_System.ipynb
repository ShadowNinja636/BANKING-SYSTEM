# %%
# %%writefile Banking_system.cpp
# #include<stdio.h>
# int func(int);
# int main()
# {
#    int status,pin=1031,pinR,menu,withd,balance_current=50000,balance_savings=100000,accounts,a,i;
#
#    int externalpin=0;
#
#
#
# for(i=2;i!=1;i=func(a))
# {
#
# printf("Please scan your card.\n");
#    //wait
#    printf("Please enter your pin:");
#    scanf("%d",&pinR);
#
#    if(pinR==pin && externalpin<=3)
#    {
#      printf("PRESS\n 1. Withdrawl\n 2. Generate Pin\n 3. Check Balance\n");
#      scanf("%d",&menu);
#      switch(menu)
#      {
#       case 1: printf("1.Current Account\n2.Savings Account\n");
#               scanf("%d", &accounts);
#               if(accounts==1)
#               {
#                 printf("Enter amount to withdraw:");
#               scanf("%d", &withd);
#               if(withd<=balance_current)
#               {
#                 balance_current=balance_current-withd;
#                 printf("Please collect your cash.\n");
#                 //wait(10);
#                 printf("Remaining balance: %d/-\n", balance_current);
#               }
#               else
#               {
#                 printf("Insufficient balance.\n");
#               }
#               }
#               else if(accounts==2)
#               {
#                 printf("Enter amount to withdraw:");
#               scanf("%d", &withd);
#               if(withd<=balance_savings)
#               {
#                 balance_savings=balance_savings-withd;
#                 printf("Please collect your cash.\n");
#                 //wait(10);
#                 printf("Remaining balance: %d/-\n", balance_savings);
#               }
#               else
#               {
#                 printf("Insufficient balance.\n");
#               }
#               }
#               break;
#       case 2: printf("Enter current pin: ");
#               scanf("%d", &pinR);
#               if(pinR==pin)
#               {
#                 printf("Enter new pin: ");
#                 scanf("%d", &pin);
#                 printf("Pin changed successfully!\n");
#               }
#               else if(pinR!=pin)
#               {
#                 printf("Invalid pin.");
#               }
#               break;
#       case 3: printf("1.Current Account\n2.Savings Account\n");
#               scanf("%d", &accounts);
#               if(accounts==1)
#               {
#                 printf("Current balance: %d\n", balance_current);
#               }
#               else if(accounts==2)
#               {
#                printf("Current balance: %d\n", balance_savings);
#               }
#               break;
#
#      }
#
#
#
#
#
#    }
#    else if(pinR!=pin)
#    {
#     printf("Invalid pin or too many attempts.\n");
#     externalpin++;
#
#    }
#
#    printf("Thank you for banking with us.\n");
#
#
# }
#
#
#
#
#  printf("Thank you for banking with us.\n");
#  printf("--Receipt--\nTranscation ID:568726866\nDate:24/10/2024 16:20:57\nAccount Number:2024065836\nCurrent Account Balance:%d\nSavings Account Balance:%d\nVisit again,Thank you for banking with us!",balance_current,balance_savings);
#
# }
#
#
# int funcnumber;
# int func(int x)
# {
#
#
#
#   printf("Do you wish to exit the transaction?\n Reply 1 for 'YES' or 2 for 'NO'");
#   scanf("%d", &funcnumber);
#    return (x=funcnumber);
#
#
#
#
#
#
# }
# Out:
# Overwriting Banking_system.cpp
